# %%
import pandas as pd
import numpy as np
df=pd.read_csv('phone_data.csv')
network=df.groupby(['network','network_type'])
network.get_group(('Vodafone','mobile'))
# Out:
#      index            date  duration  item    month   network network_type
# 1        1  15/10/14 06:58      13.0  call  2014-11  Vodafone       mobile
# 17      17  17/10/14 17:22       1.0   sms  2014-11  Vodafone       mobile
# 18      18  17/10/14 17:23       1.0   sms  2014-11  Vodafone       mobile
# 20      20  17/10/14 17:29       4.0  call  2014-11  Vodafone       mobile
# 22      22  17/10/14 17:42       1.0   sms  2014-11  Vodafone       mobile
# ..     ...             ...       ...   ...      ...       ...          ...
# 808    808  03/03/15 10:27      57.0  call  2015-03  Vodafone       mobile
# 809    809  03/03/15 14:34    1325.0  call  2015-03  Vodafone       mobile
# 812    812  04/03/15 07:02       1.0   sms  2015-03  Vodafone       mobile
# 813    813  04/03/15 07:16       1.0   sms  2015-03  Vodafone       mobile
# 826    826  13/03/15 00:39       1.0   sms  2015-03  Vodafone       mobile
#
# [215 rows x 7 columns]
